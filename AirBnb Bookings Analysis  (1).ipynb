# %% [markdown]
# # Project Summary -

# %% [markdown]
# A multidimensional set of stakeholders, including hosts, property managers, data analysts, researchers, and Airbnb itself, will benefit from an exploratory data analysis (EDA) of the data from Airbnb. The following are some major goals for conducting an EDA on Airbnb data:

# %% [markdown]
# 1. **Recognizing Data Quality**: EDA helps in assessing the quality of Airbnb data by identifying issues such as missing values, outliers, and data inconsistencies. Ensuring data integrity is crucial for conducting reliable analysis.
#
# 2. **Providing Pricing Strategies**: EDA offers guidance on pricing strategies for hosts and property managers. By analyzing historical pricing data and seasonal trends, nightly rates can be optimized to maximize revenue.
#
# 3. **Increasing Customer Satisfaction**: Through EDA, hosts can determine factors in their listings that contribute to positive guest experiences. This may involve analyzing aspects such as amenities, cleanliness, and communication with guests.
#
# 4. **Market Insights**: EDA provides investors and property owners with insights into the local Airbnb market. Analysis of factors like listing density, property types, and occupancy rates can inform decisions about property purchases and investments.
#
# 5. **Seasonal Trends**: EDA reveals seasonal booking patterns, allowing hosts to adjust their strategies for peak and off-peak times. This may include changing prices, offering discounts, or enhancing listing descriptions.
#
# 6. **Recognizing Competitive Advantages**: EDA enables hosts to identify what makes their properties stand out from competitors. This could involve analyzing unique features, locations, or services that attract guests.
#
# 7. **Targeted Marketing**: EDA provides insights into the preferences and behaviors of Airbnb guests. This information can be useful for creating marketing campaigns aimed at specific types of travelers.
#
# 8. **User Evaluations and Rankings**: Sentiment analysis and EDA can be applied to user reviews to uncover common themes and sentiment patterns. Hosts can use this data to address issues and enhance guest satisfaction.
#
# 9. **Compliance with Policies and Regulations**: EDA helps hosts and property managers ensure compliance with local laws and restrictions in regions where Airbnb regulations are enforced.
#
# 10. **Academic Research and Study**: Researchers can use Airbnb data and EDA to study the impact of short-term rentals on real estate markets, local economies, and tourism. It can also be used to explore trends related to gentrification and housing affordability.
#
# 11. **Platform Enhancements**: By analyzing user behavior, trends, and reviews, EDA can provide valuable insights for Airbnb. These insights can guide marketing strategies, policy changes, and platform improvements.
#
# 12. **Decision-Making Driven by Data**: Overall, the primary purpose of Airbnb EDA is to enable data-driven decision-making. Whether it’s about optimizing pricing, enhancing guest satisfaction, or making strategic investments, EDA provides the foundation for informed decisions within the Airbnb ecosystem.
#  are in place.

# %% [markdown]
# # GitHub Link -

# %% [markdown]
# https://github.com/sainathreddy922/Project_Airbnb_EDA/blob/main/AirBnb%20Bookings%20Analysis%20.ipynb

# %% [markdown]
# ## Problem Statement
#
# * Analyze the Airbnb data for a certain area.
#
# * Recognize seasonal changes and pricing patterns.
#
# * Determine the variables that affect occupancy rates.
#
# * Analyze customer feedback to raise customer satisfaction.
#
# * Analyze the market's competitive dynamics.
#
# * Provide hosts and property managers with useful insights.

# %% [markdown]
# ## Business Objective
#
# **EDA (Exploratory Data Analysis) on Airbnb's business purpose is to use data insights to accomplish the following objectives:**
#
# * **Optimize Host Revenue:** Hosts can increase their revenue by comprehending price trends, seasonal patterns, and elements affecting occupancy rates.
#
# * **Boost Visitor Satisfaction:** Analyzing customer feedback and reviews enables hosts to enhance their listings, resulting in improved customer satisfaction and higher ratings.
#
# * **Obtain a Competitive Advantage:** By developing distinctive selling propositions and tactical upgrades, EDA enables hosts and property managers to stand out in a crowded market.
#
# * **Provide Guidance for Data-Driven Decisions:** In order to get better results, hosts can make educated decisions about pricing tactics, property improvements, and marketing initiatives.

# %% [markdown]
# The overall goal is to promote business success for Airbnb ecosystem participants and hosts.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset Loading

# %%
# Load Dataset
air=pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# # Dataset First View

# %%
air.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # Dataset Rows & Columns count

# %%
air.shape
# Out:
# (48895, 16)

# %%
air.index
air.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# # Dataset Information

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# # What did you know about your dataset?
# Airbnb is a community built on a sharing economy. It is an online platform that allows property owners to list their place as holiday accommodation and allows travellers to find a place to stay while they are away from home.
#
# We have a Airbnb dataset consisting of 48895 rows and 16 columns.It is a mix of categorical and numeric values.Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data- data that can be analysed and used for security, business decisions ,understanding of customers and providers(hosts), behviourand performance on the platform ,guiding market intiatives, implementation of innovation additional services and much more.

# %% [markdown]
# # 2. Understanding Your Variables

# %%
list(air.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %% [markdown]
# ## Description of Dataset
#
# * **id:** Unique ID
# * **name:** Name of the listing
# * **host_id:** Unique host ID
# * **host_name:** Name of the host
# * **neighbourhood_group:** Area
# * **latitude:** Latitude range
# * **longitude:** Longitude range
# * **room_type:** Type of listing
# * **price:** Price of listing
# * **minimum_nights:** Minimum nights to be paid for
# * **number_of_reviews:** Number of reviews
# * **last_review:** Content of last review
# * **reviews_per_month:** Number of checks per month
# * **calculated_host_listing_count:** Total count of listings by the host
# * **availability_365:** Availability around the year

# %%
# Dataset Describe using .describe() for calculating some statistical data
air.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
air.describe(include=object)
# Out:
#                   name host_name neighbourhood_group neighbourhood  \
# count            48879     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                18       417               21661          3920
#
#               room_type last_review
# count             48895       38843
# unique                3        1764
# top     Entire home/apt  2019-06-23
# freq              25409        1413

# %%
#dropping columns
df=air.drop(['latitude','longitude'],axis=True)
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
new_air=df.dropna()

# %%
#now knowing the shape of our new dataset after dropping columns
new_air.shape
# Out:
# (38821, 14)

# %% [markdown]
# # 1.How does the price of Airbnb listings vary by location (city or neighborhood)?

# %%
Price_Shift=new_air.groupby('neighbourhood_group')['price'].var().sort_values(ascending=False).round(4).rename({'neighbourhood_group':'Location'})
Price_Shift
# Out:
# neighbourhood_group
# Manhattan        51290.5003
# Brooklyn         28861.9255
# Queens           28356.9466
# Staten Island     4338.0723
# Bronx             4095.8876
# Name: price, dtype: float64

# %%
plt.scatter(new_air['neighbourhood_group'],new_air['price'],color='black')
plt.xlabel('neighbourhood_group')
plt.ylabel('price')
plt.title('Price Shift')
plt.show()

# %% [markdown]
# # Conclusion
# Queens shows the greatest variation among all the other locations, whereas Bronz shows the least variation in the price listings

# %% [markdown]
# # 2.Which is the most preferred location?

# %%
#using value counts function to get the most preferred location
perferred_location=new_air.neighbourhood_group.value_counts().sort_values(ascending=False)
pd.DataFrame(perferred_location)
# Out:
#                      count
# neighbourhood_group
# Manhattan            16621
# Brooklyn             16439
# Queens                4572
# Bronx                  875
# Staten Island          314

# %%
#pie chart to enhance the understanding of the above data
plt.pie(perferred_location, labels=perferred_location.index, shadow = True)
plt.title("Preferability as per the location")
plt.show()

# %% [markdown]
# # Conclusion
#
# Brooklyn is the most preferred location and Staten Island being the least preferred.

# %% [markdown]
# # 3.What is the average preferred price by customers according to the location?

# %%
#grouping by location and aggregating the price to get the mean
avg_preferred_price=new_air.groupby('neighbourhood_group')['price'].mean().sort_values(ascending=False).round(2).rename({'neighbourhood_group':'Location','price':'Average Price'})
pd.DataFrame(avg_preferred_price)
# Out:
#                       price
# neighbourhood_group
# Manhattan            180.07
# Brooklyn             121.46
# Queens                95.78
# Staten Island         89.96
# Bronx                 79.56

# %%
#plotting a bar graph for a better understanding
plt.bar(avg_preferred_price.index,avg_preferred_price.values,color = "black")
plt.xlabel("Average preferred price")
plt.ylabel("Location")
plt.title("Average preferred price by customers according to the location")
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
#  Mahattan has the highest average price, followed by Brooklyn.
#  Bronx has the least average pric.

# %% [markdown]
# # 4.Most demanded host as per the location

# %%
# Find the host with the maximum count of listings
host_count=new_air['host_name'].value_counts()
host_counts=pd.DataFrame({'Host_name':host_count.index,'listing_count':host_count.values})
sorting_values=host_counts.sort_values(by='listing_count',ascending=False)
sorting_values.head()
# Out:
#       Host_name  listing_count
# 0       Michael            335
# 1         David            309
# 2          John            250
# 3          Alex            229
# 4  Sonder (NYC)            207

# %%
sorting_values=sorting_values.head(10)
# Define a list of custom colors for each bar
custom_colors = ['crimson', 'navy', 'lime', 'orchid', 'gold', 'teal', 'coral', 'violet', 'sienna', 'olive']
# Creating a bar plot with custom colors for each bar
plt.figure(figsize=(10, 6))
bars = plt.bar(sorting_values['Host_name'].astype(str), sorting_values['listing_count'], color=custom_colors)
plt.xlabel('Host name')
plt.ylabel('Number of Listings')
plt.title('Top Hosts by Number of Listings')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.legend(bars, sorting_values['Host_name'].astype(str), title='Host name')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# Michael is the most demanded host, followed by David and John.

# %% [markdown]
# # 5.Which neighborhoods have the most Airbnb listings within each neighborhood group?

# %%
# Group by "neighbourhood_group" and then count listings in each "neighbourhood" within the group
neighbourhood=new_air.groupby('neighbourhood')['neighbourhood_group'].value_counts().reset_index(name='listing_count')
neighbourhood=neighbourhood.sort_values(by='listing_count',ascending=False)
pd.DataFrame(neighbourhood)
# Out:
#           neighbourhood neighbourhood_group  listing_count
# 212        Williamsburg            Brooklyn           3163
# 13   Bedford-Stuyvesant            Brooklyn           3141
# 93               Harlem           Manhattan           2204
# 28             Bushwick            Brooklyn           1942
# 94       Hell's Kitchen           Manhattan           1528
# ..                  ...                 ...            ...
# 32          Castle Hill               Bronx              2
# 206          West Farms               Bronx              2
# 163        Richmondtown       Staten Island              1
# 170           Rossville       Staten Island              1
# 213         Willowbrook       Staten Island              1
#
# [218 rows x 3 columns]

# %%
top_neighbourhood = neighbourhood.groupby("neighbourhood_group").head(5)

# Pivot the DataFrame for easier plotting
pivot_df = top_neighbourhood.pivot(index="neighbourhood", columns="neighbourhood_group", values="listing_count")

# Create a horizontal bar chart using Pandas plot
ax = pivot_df.plot(kind="bar", figsize=(10, 6), color=plt.cm.viridis(np.linspace(0, 1, 5)))
ax.set_xlabel('Number of Listings')
ax.set_ylabel('Neighborhood')
ax.set_title('Top Neighborhoods by Number of Listings within Each Group')
ax.legend(title='Neighborhood Group', loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 6.What is the maximum and minimum price at a location?

# %%
#getting the highest prices as per the location by grouping by on the basis of location
highest_price=(new_air.groupby('neighbourhood_group',as_index=False)['price'].max().sort_values(['price'],ascending=False).rename(columns = {'price':'Highest price','neighbourhood_group':'Location'}))
highest_price
# Out:
#         Location  Highest price
# 1       Brooklyn          10000
# 3         Queens          10000
# 2      Manhattan           9999
# 0          Bronx            800
# 4  Staten Island            625

# %%
#getting the lowest prices as per the location by grouping by on the basis of location
lowest_price=(new_air.groupby('neighbourhood_group',as_index=False)['price'].min().sort_values(['price'],ascending=True).rename(columns = {'price':'Highest price','neighbourhood_group':'Location'}))
lowest_price

# %%
prices_merge=pd.merge(highest_price,lowest_price,on="Location")
prices_merge
# Out:
#         Location  Highest price_x  Highest price_y
# 0       Brooklyn            10000                0
# 1         Queens            10000               10
# 2      Manhattan             9999               10
# 3          Bronx              800                0
# 4  Staten Island              625               13

# %% [markdown]
# # Conclusion
# Brooklyn offers the maximum price, whereas Bronx offers the least price.

# %% [markdown]
# # 7.Which roomtype is most referred by hosts ?

# %%
# The code you provided will return a DataFrame of the top room type preferred by the maximum number of hosts.
referred_roomtype=new_air.groupby('room_type')['host_name'].count().sort_values(ascending=False).reset_index()
pd.DataFrame(referred_roomtype)
# Out:
#          room_type  host_name
# 0  Entire home/apt      20321
# 1     Private room      17654
# 2      Shared room        846

# %%
explode_values=(0,0,0.2)      #specifying the explode values for each room type in pie chart
plt.pie(referred_roomtype['host_name'],labels=referred_roomtype['room_type'],shadow=True,explode=explode_values)
plt.title("The most preferred room type by hosts")
plt.legend()
plt.show()

# %% [markdown]
# # Conclusion
# Entire home/apt is the most referred room type by the hosts, shared rooms being the least referred.

# %% [markdown]
# # 8.Comparing the availabilty of hosts

# %%
#hosts that are not available for the whole year i.e., with zero availability
host_availability_0=new_air[new_air['availability_365']==0][['host_name','availability_365']]
host_availability_0
# Out:
#            host_name  availability_365
# 4              Laura                 0
# 6              Garon                 0
# 8          MaryEllen                 0
# 14             Alina                 0
# 20             Chaya                 0
# ...              ...               ...
# 46532          Maria                 0
# 46583        Mariana                 0
# 47175  Jason & Kelly                 0
# 47218          Julio                 0
# 47614           Mike                 0
#
# [12675 rows x 2 columns]

# %%
#hosts with zero availability (top 5)
total_host_availability_0=host_availability_0.groupby('host_name')['availability_365'].count().sort_values(ascending=False)
top5_hosts=pd.DataFrame(total_host_availability_0.head())
top5_hosts
# Out:
#            availability_365
# host_name
# Michael                 128
# David                   111
# Sarah                    90
# Jessica                  75
# Daniel                   73

# %%
colors = ['mediumslateblue', 'mediumaquamarine', 'mediumpurple', 'mediumturquoise', 'mediumspringgreen']
# Create a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
for i in range(len(top5_hosts)):
    plt.bar(top5_hosts.index[i], top5_hosts.values[i], color=colors[i])

plt.xlabel("Host Name")
plt.ylabel("Number of Availability Values")
plt.title("Top 5 Hosts with Most Availability")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Conclusion
# Michael is the least available host,with the highest zero availability counts

# %%
#hosts available for more than half of the year,i.e., availability>183 days of the year
host_availability_more_than_halfyear=new_air[new_air['availability_365']>183][['host_name','availability_365']]
host_availability_more_than_halfyear
# Out:
#          host_name  availability_365
# 0             John               365
# 1         Jennifer               355
# 3      LisaRoxanne               194
# 7         Shunichi               220
# 9              Ben               188
# ...            ...               ...
# 48454       Celine               358
# 48457       Schmid               323
# 48486        Chris               322
# 48740         Matt               230
# 48790         H Ai               339
#
# [11575 rows x 2 columns]

# %%
#hosts with the most availabilty (top 5)
total_host_availability_more_than_halfyear=host_availability_more_than_halfyear.groupby('host_name')['availability_365'].count().sort_values(ascending=False)
top5_hosts=pd.DataFrame(total_host_availability_more_than_halfyear.head())
top5_hosts
# Out:
#               availability_365
# host_name
# Sonder (NYC)               184
# David                      105
# John                        95
# Michael                     89
# Alex                        71

# %%
colors = ['gold', 'darkorange', 'crimson', 'darkorchid', 'steelblue']
# Create a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
for i in range(len(top5_hosts)):
    plt.bar(top5_hosts.index[i], top5_hosts.values[i], color=colors[i])

plt.xlabel("Host Name")
plt.ylabel("Number of Availability Values")
plt.title("Top 5 Hosts with Most Availability")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Conclusion
# Sonder is the most available host,with the maximum availability counts

# %%
#merging the dataframe of hosts with zero avilability and with more than 183 days of availability
merged=pd.merge(host_availability_0,host_availability_more_than_halfyear,how="outer")
merged
# Out:
#       host_name  availability_365
# 0          John               365
# 1          John               365
# 2          John               365
# 3          John               365
# 4          John               365
# ...         ...               ...
# 16474    Celine               358
# 16475    Schmid               323
# 16476     Chris               322
# 16477      Matt               230
# 16478      H Ai               339
#
# [16479 rows x 2 columns]

# %% [markdown]
# # 9.Which host offers the economical prices (between 100 and 250)?

# %%
economical_price=new_air[(new_air['price']>=100 )& (new_air['price']<=250)][['host_name','price']].sort_values(by='price',ascending=False)
economical_price
# Out:
#       host_name  price
# 35912     Olena    250
# 41712  Veronica    250
# 24812     Merve    250
# 24816     Helen    250
# 9431       Evan    250
# ...         ...    ...
# 18745    Harvey    100
# 27227   Camille    100
# 6349      Petya    100
# 39375    Nicole    100
# 48805    Blaine    100
#
# [17419 rows x 2 columns]

# %%
#which host offers the most economical prices (top 5)
host_offering_economical_prices=economical_price.groupby('host_name')['price'].count().sort_values(ascending=False)
host_offering_economical_prices.head()
# Out:
# host_name
# Michael         157
# David           147
# Sonder (NYC)    141
# Alex            102
# John             93
# Name: price, dtype: int64

# %%
#visual representation of the top 5 hosts offering economical prices
plt.figure(figsize=(10,6))
bars=plt.bar(host_offering_economical_prices.head().index,host_offering_economical_prices.head().values,color='blue')
plt.xlabel("Hosts Name")
plt.ylabel("Counts of Economical Prices")
plt.title("Top 5 Hosts Offering the Most Economical Prices")
plt.show()

# %% [markdown]
# # Conclusion
# Michael offers most of the economical prices

# %% [markdown]
# # 10.What are the top 10 neighborhoods with the highest average nightly prices for accommodations, as depicted in the 'Average Nightly Price Neighborhood' plot?

# %%
average_prices_by_neighborhood=new_air.groupby('neighbourhood')['price'].mean().head(10).round(2)
average_prices_by_neighborhood
# Out:
# neighbourhood
# Allerton                       90.59
# Arden Heights                  67.25
# Arrochar                      118.25
# Arverne                       158.52
# Astoria                       116.02
# Bath Beach                     84.80
# Battery Park City             182.19
# Bay Ridge                     105.37
# Bay Terrace                   118.80
# Bay Terrace, Staten Island    102.50
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.plot(average_prices_by_neighborhood.head(10).index,average_prices_by_neighborhood.head(10).values,marker='o',color='gold')
plt.xlabel('Neighborhood')
plt.ylabel('Average Nightly Price')
plt.title('Average Nightly Price by Neighborhood')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusion
#
# Varied Neighborhood Prices: Prices vary significantly among the top 10 neighborhoods.
#
# Budget Consideration: Travelers can use this graph to consider budget-friendly options when choosing a neighborhood to stay in.

# %% [markdown]
# # 11.Relation between neighbourhood group and availability of rooms

# %%
plt.figure(figsize=(10,10))
sns.set_style('white')
ax = sns.boxplot(data=new_air, x='neighbourhood_group',y='availability_365',palette='plasma')
ax.set_title('Relation between Neighbourhood group & Availability of rooms').set_fontsize('15')
ax.set_ylabel('Availability 365 Days').set_fontsize('15')
ax.set_xlabel('Neighbourhood Group').set_fontsize('15')
ax.set_xticklabels(ax.get_xticklabels(), size = '15')
plt.show()

# %% [markdown]
# # Conclusion:
#
# The boxplot shows how room availability (365 days) varies across different neighborhood groups.
# It highlights differences in median availability, spread, and potential outliers, aiding in understanding neighborhood-specific availability trends.

# %% [markdown]
# ## Manipulations Done and Insights
#
# 1. **Data Cleaning and Preprocessing:**
#    * Identified the number of null values.
#    * Removed the null values using `dropna()`.
#    * Dropped unnecessary columns that were not useful for further data analysis (e.g., dropped `latitude`, `longitude`).
#
# 2. **Data Analysis:**
#    * Analyzed the data using various functions and methods.
#    * Examples include identifying the most demanded host, analyzing price variation with location, determining maximum and minimum prices, and finding hosts offering economical prices.
#
# 3. **Exploratory Data Analysis (EDA):**
#    * Conducted univariate analysis to understand distributions and trends in individual features.
#    * Performed bivariate analysis to explore relationships between pairs of variables.
#    * Utilized visualizations like histograms, scatter plots, and box plots for better insights.
#
# 4. **Correlation Analysis:**
#    * Investigated correlations between numerical features to identify potential relationships.

# %% [markdown]
# ## How Can This Analysis Help with the Business Objectives?
#
# Our analysis on the Airbnb dataset can help with the business purposes in the following ways:
#
# * **Pricing Optimization:** Set competitive pricing strategies.
#
# * **Market Segmentation:** Tailor offerings to different customer groups.
#
# * **Property Investment:** Identify profitable neighborhoods.
#
# * **Competitor Analysis:** Understand the competitive landscape.
#
# * **Occupancy Forecasting:** Predict future occupancy rates.
#
# * **Customer Satisfaction:** Improve service quality based on reviews.
#
# * **Marketing Insights:** Target marketing efforts effectively.
#
# * **Regulatory Compliance:** Ensure compliance with local laws.
#
# * **Property Management:** Address maintenance and cleanliness issues.
#
# * **Expansion Planning:** Identify growth opportunities in new markets.

# %% [markdown]
# ## Conclusion
#
# Following are a few conclusions that can be drawn from our analysis:
#
# * **Queens (Name of Listings):** Listings in Queens show the greatest variation in prices with location.
#
# * **Most Preferred Location:** Brooklyn is the most preferred location, while Staten Island is the least preferred.
#
# * **Highest Average Price:** Manhattan has the highest average price.
#
# * **Most Demanded Host:** Michael is the most demanded host.
#
# * **Preferred Room Type:** Entire home/apartment is the most referred room type by the hosts, with shared rooms being the least referred.
#
# * **Economical Prices:** Michael offers most of the economical prices.
#
# * **Most Available Host:** Sonder is the most available host.
